# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup

# %%
resp = requests.get("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for j in range(0, 10):
    table = tables[j]
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        if (len(cells) == 1):
            year = cells[0].text.split("(")[0].split("/")[0]
        if (len(cells) == 2):
            title = cells[0].find("a").text
            winner = False
            if rows[i].has_attr("style"):
                if rows[i]["style"].split(":")[1] == "#FAEB86":
                    winner = True
            producers = cells[1].text.replace("\n", "").replace("and ", "").split(",")

            rowsList.append({
                "Title": title,
                "producers":producers,
                "winner":winner,
                "year": year
            })
bestpicture = pd.DataFrame(rowsList)
bestpicture.head()
# Out:
#                  Title                 producers  winner  year
# 0                Wings  [Paramount Famous Lasky]    True  1927
# 1           The Racket       [The Caddo Company]   False  1927
# 2           7th Heaven                     [Fox]   False  1927
# 3  The Broadway Melody     [Metro-Goldwyn-Mayer]    True  1928
# 4                Alibi     [Feature Productions]   False  1928

# %%
resp = requests.get("https://en.wikipedia.org/wiki/BAFTA_Award_for_Best_Film")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for table in tables:
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        if (len(cells) == 1):
            year = cells[0].text.split("(")[0].split("/")[0]
        else:
            if (len(cells) == 5):
                title = cells[1].find("a").text
                winner = True
            if (len(cells) == 4):
                title = cells[0].find("a").text
                winner = False
                
            rowsList.append({
                "Title": title,
                "BAFTA":winner,
                "year": year
            })
bafta = pd.DataFrame(rowsList)
bafta.head()
# Out:
#    BAFTA                        Title  year
# 0   True  The Best Years of Our Lives  1947
# 1   True                       Hamlet  1948
# 2  False                    Crossfire  1948
# 3  False              The Fallen Idol  1948
# 4  False             Monsieur Vincent  1948

# %%
resp = requests.get("https://en.wikipedia.org/wiki/National_Board_of_Review_Award_for_Best_Film")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for table in tables:
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        title = cells[1].text.replace(" ‡", "").replace(" §", "").replace(" †", "")
        year = cells[0].text
                
        rowsList.append({
            "Title": title,
            "NBRA": True,
            "year": year
        })
nbra = pd.DataFrame(rowsList)

# %%
resp = requests.get("https://en.wikipedia.org/wiki/Golden_Globe_Award_for_Best_Motion_Picture_%E2%80%93_Drama")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for table in tables:
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        if (len(cells) == 4):
            year = cells[0].text
            title = cells[1].find("a").text
            winner = True
        if (len(cells) == 3):
            title = cells[0].find("a").text
            winner = False
                
        rowsList.append({
            "Title": title,
            "GOLDENGLOBE":winner,
            "year": year
        })
goldenglobe = pd.DataFrame(rowsList)

# %%
resp = requests.get("https://en.wikipedia.org/wiki/Satellite_Award_for_Best_Film#Drama_%281996%E2%80%932009,_2018%29")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for table in tables:
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        if (len(cells) == 1):
            year = cells[0].text.split("\n")[0]
        else:
            if (len(cells) == 3):
                year = cells[0].text.split("\n")[0]
                title = cells[1].find("a").text
                winner = True
            if (len(cells) == 2):
                title = cells[0].find("a").text
                winner = False

            rowsList.append({
                "Title": title,
                "SATELLITE": winner,
                "year": year
            })
satellite = pd.DataFrame(rowsList)

# %%
resp = requests.get("https://en.wikipedia.org/wiki/Directors_Guild_of_America_Award_for_Outstanding_Directing_%E2%80%93_Feature_Film")
soup = BeautifulSoup(resp.content, "html.parser")
tables = soup.find_all("table", {"class": "wikitable"})
rowsList = []
year = ""
for table in tables:
    tbody = table.find("tbody")
    rows = tbody.find_all("tr")
    for i in range(1, len(rows)):
        cells = rows[i].find_all("td")
        if (len(cells) == 4):
            year = cells[0].text.split("(")[0]
            title = cells[2].find("a").text
            winner = True
        if (len(cells) == 2):
            title = cells[1].find("a").text
            winner = False

        rowsList.append({
            "Title": title,
            "DGA": winner,
            "year": year
        })
dga = pd.DataFrame(rowsList)

# %%
movies = pd.read_csv("./movies.csv")
tags = pd.read_csv("./tags.csv")
movie_tags = movies.merge(tags, on=["movieId"])
movie_tags["Title"] = movie_tags.title.str.split(" ")
movie_tags["Title"] = movie_tags.Title.str[:-1]
movie_tags["Title"] = movie_tags["Title"].str.join(' ')
movie_tags = movie_tags.drop(["genres", "userId", "timestamp", "title"], axis=1)
movie_tags.head()
# Out:
#    movieId               tag      Title
# 0        1             pixar  Toy Story
# 1        1             pixar  Toy Story
# 2        1               fun  Toy Story
# 3        2           fantasy    Jumanji
# 4        2  magic board game    Jumanji

# %%
movie_tags_joined = pd.DataFrame(movie_tags.groupby(movie_tags['Title']).tag.apply(lambda a: ", ".join(a)))
movie_tags_joined = movie_tags_joined.reset_index()

# %%
dfs = []
for name in bestpicture["Title"]:
    name = name.replace(" ", "+")
    resp = requests.get("http://www.omdbapi.com/?t=" + name + "&plot=full&apikey=8de699a6")
    movie_json = resp.json()
    movie_df = json_normalize(movie_json)
    dfs.append(movie_df)

# %%
imdb = pd.concat(dfs, ignore_index=True, sort=True)

# %%
oscar_movies = pd.concat([bestpicture, imdb.drop(["Title"], axis=1)], axis=1)
oscar_movies = oscar_movies.drop(["DVD", "Error", "BoxOffice", "Poster", "Type", "Website", "totalSeasons"], axis=1)

oscar_movies = oscar_movies.merge(bafta.drop(["year"], axis=1), on=["Title"], how="left")
oscar_movies = oscar_movies.merge(nbra.drop(["year"], axis=1), on=["Title"], how="left")
oscar_movies = oscar_movies.merge(goldenglobe.drop(["year"], axis=1), on=["Title"], how="left")
oscar_movies = oscar_movies.merge(satellite.drop(["year"], axis=1), on=["Title"], how="left")
oscar_movies = oscar_movies.merge(dga.drop(["year"], axis=1), on=["Title"], how="left")
oscar_movies = oscar_movies.merge(movie_tags_joined, on=["Title"], how="left")
oscar_movies.BAFTA.fillna(False, inplace=True)
oscar_movies.NBRA.fillna(False, inplace=True)
oscar_movies.GOLDENGLOBE.fillna(False, inplace=True)
oscar_movies.SATELLITE.fillna(False, inplace=True)
oscar_movies.DGA.fillna(False, inplace=True)
oscar_movies.tag.fillna("none", inplace=True)
oscar_movies.to_csv(path_or_buf="./oscar_movies.csv", index=False)
#oscar_movies[oscar_movies.tag != "none"]
oscar_movies
# Out:
#                                          Title  \
# 0                                        Wings
# 1                                   The Racket
# 2                                   7th Heaven
# 3                          The Broadway Melody
# 4                                        Alibi
# 5                              Hollywood Revue
# 6                               In Old Arizona
# 7                                  The Patriot
# 8               All Quiet on the Western Front
# 9                                The Big House
# 10                                    Disraeli
# 11                                The Divorcee
# 12                             The Love Parade
# 13                                    Cimarron
# 14                                  East Lynne
# 15                              The Front Page
# 16                                      Skippy
# 17                                 Trader Horn
# 18                                 Grand Hotel
# 19                                  Arrowsmith
# 20                                    Bad Girl
# 21                                   The Champ
# 22                             Five Star Final
# 23                           One Hour with You
# 24                            Shanghai Express
# 25                      The Smiling Lieutenant
# 26                                   Cavalcade
# 27                                 42nd Street
# 28                          A Farewell to Arms
# 29           I Am a Fugitive from a Chain Gang
# ..                                         ...
# 528                                The Martian
# 529                               The Revenant
# 530                                       Room
# 531                                  Moonlight
# 532                                    Arrival
# 533                                     Fences
# 534                              Hacksaw Ridge
# 535                         Hell or High Water
# 536                             Hidden Figures
# 537                                 La La Land
# 538                                       Lion
# 539                      Manchester by the Sea
# 540                         The Shape of Water
# 541                       Call Me by Your Name
# 542                               Darkest Hour
# 543                                    Dunkirk
# 544                                    Get Out
# 545                                  Lady Bird
# 546                             Phantom Thread
# 547                                   The Post
# 548  Three Billboards Outside Ebbing, Missouri
# 549                                 Green Book
# 550                              Black Panther
# 551                             BlacKkKlansman
# 552                          Bohemian Rhapsody
# 553                              The Favourite
# 554                                       Roma
# 555                             A Star Is Born
# 556                             A Star Is Born
# 557                                       Vice
#
#                                              producers  winner  year  \
# 0                             [Paramount Famous Lasky]    True  1927
# 1                                  [The Caddo Company]   False  1927
# 2                                                [Fox]   False  1927
# 3                                [Metro-Goldwyn-Mayer]    True  1928
# 4                                [Feature Productions]   False  1928
# 5                                [Metro-Goldwyn-Mayer]   False  1928
# 6                                                [Fox]   False  1928
# 7                             [Paramount Famous Lasky]   False  1928
# 8                                          [Universal]    True  1929
# 9                                       [Cosmopolitan]   False  1929
# 10                                      [Warner Bros.]   False  1929
# 11                               [Metro-Goldwyn-Mayer]   False  1929
# 12                            [Paramount Famous Lasky]   False  1929
# 13                                         [RKO Radio]    True  1930
# 14                                               [Fox]   False  1930
# 15                                 [The Caddo Company]   False  1930
# 16                                  [Paramount Publix]   False  1930
# 17                               [Metro-Goldwyn-Mayer]   False  1930
# 18                               [Metro-Goldwyn-Mayer]    True  1931
# 19                        [Samuel Goldwyn Productions]   False  1931
# 556  Lady Gaga, Bradley Cooper, Sam Elliott, Andrew...
# 557  Christian Bale, Amy Adams, Steve Carell, Sam R...
#
#                                                 Awards  \
# 0         Won 2 Oscars. Another 3 wins & 1 nomination.
# 1                                                  N/A
# 2    Nominated for 1 Primetime Emmy. Another 20 win...
# 3                  Won 1 Oscar. Another 2 nominations.
# 4                                               1 win.
# 5                                                  N/A
# 6                  Won 1 Oscar. Another 4 nominations.
# 7    Nominated for 3 Oscars. Another 8 wins & 18 no...
# 8        Won 2 Oscars. Another 5 wins & 2 nominations.
# 9                 Won 2 Oscars. Another 2 nominations.
# 10        Won 1 Oscar. Another 2 wins & 2 nominations.
# 11                 Won 1 Oscar. Another 3 nominations.
# 12              Nominated for 6 Oscars. Another 1 win.
# 13       Won 3 Oscars. Another 2 wins & 4 nominations.
# 14                                                 N/A
# 15   Nominated for 3 Golden Globes. Another 2 wins ...
# 16                                              1 win.
# 17                                                 N/A
# 18          Won 1 Oscar. Another 1 win & 1 nomination.
# 19                                                 N/A
# 20                 Won 2 Oscars. Another 1 nomination.
# 21   Nominated for 1 Oscar. Another 2 wins & 6 nomi...
# 22                                                 N/A
# 23                                                 N/A
# 24                 Won 1 Oscar. Another 2 nominations.
# 25                                                 N/A
# 26         Won 3 Oscars. Another 1 win & 1 nomination.
# 27              Nominated for 2 Oscars. Another 1 win.
# 28        Won 2 Oscars. Another 1 win & 2 nominations.
# 29             Nominated for 3 Oscars. Another 3 wins.
# ..                                                 ...
# 528  Nominated for 7 Oscars. Another 37 wins & 185 ...
# 529   Won 3 Oscars. Another 86 wins & 181 nominations.
# 530   Won 1 Oscar. Another 103 wins & 136 nominations.
# 531  Won 3 Oscars. Another 220 wins & 270 nominations.
# 532    Won 1 Oscar. Another 64 wins & 251 nominations.
# 533    Won 1 Oscar. Another 52 wins & 106 nominations.
# 534   Won 2 Oscars. Another 46 wins & 111 nominations.
# 535  Nominated for 4 Oscars. Another 42 wins & 157 ...
# 536  Nominated for 3 Oscars. Another 36 wins & 81 n...
# 537  Won 6 Oscars. Another 215 wins & 254 nominations.
# 538  Nominated for 6 Oscars. Another 49 wins & 80 n...
# 539  Won 2 Oscars. Another 117 wins & 243 nominations.
# 540  Won 4 Oscars. Another 101 wins & 293 nominations.
# 541    Won 1 Oscar. Another 82 wins & 196 nominations.
# 542    Won 2 Oscars. Another 40 wins & 63 nominations.
# 543   Won 3 Oscars. Another 51 wins & 197 nominations.
# 544   Won 1 Oscar. Another 122 wins & 181 nominations.
# 545  Nominated for 5 Oscars. Another 102 wins & 191...
# 546     Won 1 Oscar. Another 46 wins & 93 nominations.
# 547  Nominated for 2 Oscars. Another 16 wins & 97 n...
# 548  Won 2 Oscars. Another 104 wins & 193 nominations.
# 549                                                N/A
# 550                                    14 nominations.
# 551                                                N/A
# 552                                                N/A
# 553                                                N/A
# 554                                                N/A
# 555                                      1 nomination.
# 556                                      1 nomination.
# 557                                                N/A
#
#                                                Country  \
# 0                                                  USA
# 1                                                  USA
# 2                                                  USA
# 3                                                  USA
# 4                                          Netherlands
# 5                                                  USA
# 6                                                  USA
# 7                                         USA, Germany
# 8                                                  USA
# 9                                                  USA
# 10                                                 USA
# 11                                                 USA
# 12                                                 USA
# 13                                                 USA
# 14                                                 USA
# 15                                                 USA
# 16                                           Australia
# 17                                                 USA
# 18                                                 USA
# 19                                                 USA
# 20                                                 USA
# 21                                                 USA
# 22                                                 USA
# 23                                                 USA
# 24                                                 USA
# 25                                                 USA
# 26                                                 USA
# 27                                                 USA
# 28                                                 USA
# 29                                                 USA
# ..                                                 ...
# 528                                            UK, USA
# 529                             USA, Hong Kong, Taiwan
# 530                           Ireland, Canada, UK, USA
# 531                                                USA
# 532                                                USA
# 533                                        USA, Canada
# 534                                     Australia, USA
# 535                                                USA
# 536                                                USA
# 537                                     USA, Hong Kong
# 538                                 UK, Australia, USA
# 539                                                USA
# 540                                                USA
# 541  Italy, France, Brazil, USA, Netherlands, Germa...
# 542                                            UK, USA
# 543                       UK, Netherlands, France, USA
# 544                                         Japan, USA
# 545                                                USA
# 546                                            USA, UK
# 547                                            USA, UK
# 548                                            UK, USA
# 549                                                USA
# 550                                                USA
# 551                                                USA
# 552                                            UK, USA
# 553                                   Ireland, UK, USA
# 554                                        Mexico, USA
# 555                                                USA
# 556                                                USA
# 557                                                USA
#
#                                               Director  \
# 0         William A. Wellman, Harry d'Abbadie d'Arrast
# 1    John Cromwell, Mel Ferrer, Tay Garnett, Nichol...
# 2                                                  N/A
# 3                                       Harry Beaumont
# 4                                      Johan Nijenhuis
# 5                     Charles Reisner, Christy Cabanne
# 6                                      Irving Cummings
# 7                                      Roland Emmerich
# 8                                      Lewis Milestone
# 9                            George W. Hill, Ward Wing
# 10                                     Alfred E. Green
# 11                                   Robert Z. Leonard
# 12                                      Ernst Lubitsch
# 13                                      Wesley Ruggles
# 14                                         Frank Lloyd
# 15                                        Billy Wilder
# 16                                                 N/A
# 17                                       W.S. Van Dyke
# 18                                     Edmund Goulding
# 19                                           John Ford
# 20                                       Frank Borzage
# 21                                   Franco Zeffirelli
# 22                                        Mervyn LeRoy
# 23                        George Cukor, Ernst Lubitsch
# 24                                 Josef von Sternberg
# 25                                      Ernst Lubitsch
# 26                                         Frank Lloyd
# 27                                         Lloyd Bacon
# 28                                       Frank Borzage
# 29                                        Mervyn LeRoy
# ..                                                 ...
# 528                                       Ridley Scott
# 529                              Alejandro G. Iñárritu
# 530                                   Lenny Abrahamson
# 531                                      Barry Jenkins
# 532                                   Denis Villeneuve
# 533                                  Denzel Washington
# 534                                         Mel Gibson
# 535                                    David Mackenzie
# 536                                     Theodore Melfi
# 537                                    Damien Chazelle
# 538                                        Garth Davis
# 539                                   Kenneth Lonergan
# 540                                 Guillermo del Toro
# 541                                    Luca Guadagnino
# 542                                         Joe Wright
# 543                                  Christopher Nolan
# 544                                       Jordan Peele
# 545                                       Greta Gerwig
# 546                               Paul Thomas Anderson
# 547                                   Steven Spielberg
# 548                                    Martin McDonagh
# 549                                     Peter Farrelly
# 550                                       Ryan Coogler
# 551                                          Spike Lee
# 552                                       Bryan Singer
# 553                                   Yorgos Lanthimos
# 554                                     Alfonso Cuarón
# 555                                     Bradley Cooper
# 556                                     Bradley Cooper
# 557                                         Adam McKay
#
#                                             Genre  \
# 0                     Drama, Romance, War, Action
# 1                         Crime, Drama, Film-Noir
# 2                          Drama, Family, Romance
# 3                         Drama, Musical, Romance
# 4                                          Comedy
# 5                                         Musical
# 6                                Romance, Western
# 7                     Action, Drama, History, War
# 8                                      Drama, War
# 9                          Crime, Drama, Thriller
# 10                      Biography, Drama, History
# 11                                 Romance, Drama
# 12                       Comedy, Musical, Romance
# 13                                 Drama, Western
# 14                                          Drama
# 15                         Comedy, Drama, Romance
# 16                              Adventure, Family
# 17              Action, Adventure, Drama, Romance
# 18                                 Drama, Romance
# 19                                          Drama
# 20                                 Drama, Romance
# 21                                   Drama, Sport
# 22                                   Crime, Drama
# 23                       Comedy, Musical, Romance
# 24            Adventure, Drama, Romance, Thriller
# 25                       Comedy, Romance, Musical
# 26                            Drama, Romance, War
# 27                       Comedy, Musical, Romance
# 28                            Drama, Romance, War
# 29                        Crime, Drama, Film-Noir
# ..                                            ...
# 528                      Adventure, Drama, Sci-Fi
# 529  Action, Adventure, Biography, Drama, Western
# 530                               Drama, Thriller
# 531                                         Drama
# 532              Drama, Mystery, Sci-Fi, Thriller
# 533                                         Drama
# 534                Biography, Drama, History, War
# 535       Action, Crime, Drama, Thriller, Western
# 536                     Biography, Drama, History
# 537        Comedy, Drama, Music, Musical, Romance
# 538                              Biography, Drama
# 539                                         Drama
# 540  Adventure, Drama, Fantasy, Romance, Thriller
# 541                                Drama, Romance
# 542                Biography, Drama, History, War
# 543         Action, Drama, History, Thriller, War
# 544                     Horror, Mystery, Thriller
# 545                                 Comedy, Drama
# 546                                Drama, Romance
# 547           Biography, Drama, History, Thriller
# 548                                  Crime, Drama
# 549               Biography, Comedy, Drama, Music
# 550                     Action, Adventure, Sci-Fi
# 551                       Biography, Crime, Drama
# 552                       Biography, Drama, Music
# 553             Biography, Comedy, Drama, History
# 554                                         Drama
# 555                         Drama, Music, Romance
# 556                         Drama, Music, Romance
# 557                      Biography, Comedy, Drama
#
#                                               Language  \
# 0                                              English
# 1                                              English
# 2                                              English
# 3                                              English
# 4                                                Dutch
# 5                                              English
# 6                            English, Spanish, Italian
# 7                                              English
# 8                       English, French, German, Latin
# 9                                     English, Russian
# 10                                             English
# 11                                     English, French
# 12                                     English, French
# 13                                     English, French
# 14                                             English
# 15                                             English
# 16                                             English
# 17                                    English, Swahili
# 18                                    English, Russian
# 19                           English, Italian, Swedish
# 20                                             English
# 21                                             English
# 22                                             English
# 23                                     English, French
# 24                  English, French, Cantonese, German
# 25                                     English, French
# 26                                             English
# 27                                             English
# 28                                             English
# 29                                             English
# ..                                                 ...
# 528                                  English, Mandarin
# 529                            English, Pawnee, French
# 530                                            English
# 531                                            English
# 532                         English, Russian, Mandarin
# 533                                            English
# 534                                  English, Japanese
# 535                                            English
# 536                                            English
# 537                                            English
# 538                            English, Hindi, Bengali
# 539                                            English
# 540   English, American Sign Language, Russian, French
# 541           English, Italian, French, German, Hebrew
# 542                            English, French, German
# 543                            English, French, German
# 544                                            English
# 545                                   English, Spanish
# 546                                    English, French
# 547                                            English
# 548                                            English
# 549                  English, Italian, Russian, German
# 550              English, Swahili, Nama, Xhosa, Korean
# 551                                            English
# 552                                            English
# 553                                            English
# 554  Spanish, North American Indian, English, Norwe...
# 555                                            English
# 556                                            English
# 557                                    English, Arabic
#
#                            ...                               Year     imdbID  \
# 0                          ...                               1927  tt0018578
# 1                          ...                               1951  tt0043955
# 2                          ...                          1996–2007  tt0115083
# 3                          ...                               1929  tt0019729
# 4                          ...                               2008  tt0827170
# 5                          ...                               1929  tt0019993
# 6                          ...                               1928  tt0020018
# 7                          ...                               2000  tt0187393
# 8                          ...                               1930  tt0020629
# 9                          ...                               1930  tt0020686
# 10                         ...                               1929  tt0019823
# 11                         ...                               1930  tt0020827
# 12                         ...                               1929  tt0020112
# 13                         ...                               1931  tt0021746
# 14                         ...                               1931  tt0021826
# 15                         ...                               1974  tt0071524
# 16                         ...                              1967–  tt0060025
# 17                         ...                               1931  tt0022495
# 18                         ...                               1932  tt0022958
# 19                         ...                               1931  tt0021622
# 20                         ...                               1931  tt0021635
# 21                         ...                               1979  tt0078950
# 22                         ...                               1931  tt0021873
# 23                         ...                               1932  tt0023303
# 24                         ...                               1932  tt0023458
# 25                         ...                               1931  tt0022074
# 26                         ...                               1933  tt0023876
# 27                         ...                               1933  tt0024034
# 28                         ...                               1932  tt0022879
# 29                         ...                               1932  tt0023042
# ..                         ...                                ...        ...
# 528                        ...                               2015  tt3659388
# 529                        ...                               2015  tt1663202
# 530                        ...                               2015  tt3170832
# 531                        ...                               2016  tt4975722
# 532                        ...                               2016  tt2543164
# 533                        ...                               2016  tt2671706
# 534                        ...                               2016  tt2119532
# 535                        ...                               2016  tt2582782
# 536                        ...                               2016  tt4846340
# 537                        ...                               2016  tt3783958
# 538                        ...                               2016  tt3741834
# 539                        ...                               2016  tt4034228
# 540                        ...                               2017  tt5580390
# 541                        ...                               2017  tt5726616
# 542                        ...                               2017  tt4555426
# 543                        ...                               2017  tt5013056
# 544                        ...                               2017  tt5052448
# 545                        ...                               2017  tt4925292
# 546                        ...                               2017  tt5776858
# 547                        ...                               2017  tt6294822
# 548                        ...                               2017  tt5027774
# 549                        ...                               2018  tt6966692
# 550                        ...                               2018  tt1825683
# 551                        ...                               2018  tt7349662
# 552                        ...                               2018  tt1727824
# 553                        ...                               2018  tt5083738
# 554                        ...                               2018  tt6155172
# 555                        ...                               2018  tt1517451
# 556                        ...                               2018  tt1517451
# 557                        ...                               2018  tt6266538
#
#     imdbRating imdbVotes  BAFTA   NBRA GOLDENGLOBE SATELLITE    DGA  \
# 0          7.7     9,884  False  False       False     False  False
# 1          6.8     2,056  False  False       False     False  False
# 2          5.2    22,707  False  False       False     False  False
# 3          6.2     5,601  False  False       False     False  False
# 4          5.7       796  False  False       False     False  False
# 5          7.4     1,586  False  False       False     False  False
# 6          5.7       668  False  False       False     False  False
# 7          7.2   234,528  False  False       False     False  False
# 8          8.1    52,868  False  False       False     False  False
# 9          7.2     1,589  False  False       False     False  False
# 10         6.4       809  False  False       False     False  False
# 11         6.9     2,174  False  False       False     False  False
# 12         7.2     1,731  False  False       False     False  False
# 13         6.0     4,602  False  False       False     False  False
# 14         6.9        89  False  False       False     False  False
# 15         7.3    10,855  False  False       False     False  False
# 16         6.4       803  False  False       False     False  False
# 17         6.4       793  False  False       False     False  False
# 18         7.5    15,417  False  False       False     False  False
# 19         6.2     1,136  False  False       False     False  False
# 20         6.6       889  False  False       False     False  False
# 21         6.8     7,129  False  False       False     False  False
# 22         7.3     1,383  False  False       False     False  False
# 23         7.3     1,794  False  False       False     False  False
# 24         7.4     6,383  False  False       False     False  False
# 25         7.8     2,908  False  False       False     False  False
# 26         6.0     3,839  False  False       False     False  False
# 27         7.6     9,459  False  False       False     False  False
# 28         6.5     4,113  False  False       False     False  False
# 29         8.1    10,391  False   True       False     False  False
# ..         ...       ...    ...    ...         ...       ...    ...
# 528        8.0   659,851  False  False       False     False  False
# 529        8.0   603,483   True  False        True     False   True
# 530        8.2   303,978  False  False       False     False  False
# 531        7.4   218,370  False  False        True     False  False
# 532        7.9   496,569  False  False       False     False  False
# 533        7.2    83,370  False  False       False     False  False
# 534        8.1   355,491  False  False       False     False  False
# 535        7.6   171,021  False  False       False     False  False
# 536        7.8   165,823  False  False       False     False  False
# 537        8.0   419,427   True  False       False      True   True
# 538        8.1   174,796  False  False       False     False  False
# 539        7.8   207,489  False   True       False     False  False
# 540        7.3   292,314  False  False       False     False   True
# 541        7.9   143,182  False  False       False     False  False
# 542        7.4   131,051  False  False       False     False  False
# 543        7.9   449,117  False  False       False     False  False
# 544        7.7   367,135  False  False       False     False  False
# 545        7.4   166,531  False  False       False     False  False
# 546        7.5    79,989  False  False       False     False  False
# 547        7.2   101,753  False   True       False     False  False
# 548        8.2   323,099   True  False        True     False  False
# 549        8.3    60,066  False   True       False     False  False
# 550        7.3   469,075  False  False       False     False  False
# 551        7.5   117,903  False  False       False     False  False
# 552        8.1   271,569  False  False        True     False  False
# 553        7.8    64,262  False  False       False     False  False
# 554        7.9    89,226   True  False       False     False   True
# 555        7.9   186,913  False  False       False     False  False
# 556        7.9   186,913  False  False       False     False  False
# 557        7.2    41,254  False  False       False     False  False
#
#                                                    tag
# 0                                                 none
# 1                                                 none
# 2                                                 none
# 3                                                 none
# 4                                                 none
# 5                                                 none
# 6                                                 none
# 7                                                 none
# 8                                                 none
# 9                                                 none
# 10                                                none
# 11                                                none
# 12                                                none
# 13                                                none
# 14                                                none
# 15                                                none
# 16                                                none
# 17                                                none
# 18                                                none
# 19                                                none
# 20                                                none
# 21                                                none
# 22                                                none
# 23                                                none
# 24                                                none
# 25                                                none
# 26                                                none
# 27                                                none
# 28                                                none
# 29                                                none
# ..                                                 ...
# 528                                              smart
# 529  leonardo DiCarpio, survival, tom hardy, visual...
# 530                                   moving, touching
# 531                                               none
# 532  beautiful visuals, Cerebral, cinematography, g...
# 533                                               none
# 534                                               none
# 535                                               none
# 536                                               none
# 537                    Bittersweet, visually appealing
# 538                                               none
# 539                                               none
# 540                             atmospheric, dreamlike
# 541                                               none
# 542                                               none
# 543                        brilliant, inspiring, tense
# 544                                               none
# 545                                               none
# 546                                               none
# 547                                               none
# 548                                               none
# 549                                               none
# 550                                               none
# 551                                               none
# 552                                               none
# 553                                               none
# 554                                               none
# 555                                               none
# 556                                               none
# 557                                               none
#
# [558 rows x 29 columns]
